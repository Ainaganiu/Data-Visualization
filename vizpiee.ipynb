# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = 'C:/Users/User/Documents/Python Vizualization/df_Canada.csv'
dfc= pd.read_csv(df1)

# %%
dfc
# Out:
#               Country        Type    Coverage  AREA AreaName   REG  \
# 0               India  Immigrants  Foreigners   935     Asia  5501
# 1               China  Immigrants  Foreigners   935     Asia   906
# 2         Philippines  Immigrants  Foreigners   935     Asia   920
# 3                  UK  Immigrants  Foreigners   908   Europe   924
# 4            Pakistan  Immigrants  Foreigners   935     Asia  5501
# ..                ...         ...         ...   ...      ...   ...
# 190    American Samoa  Immigrants  Foreigners   909  Oceania   957
# 191        San Marino  Immigrants  Foreigners   908   Europe   925
# 192  Marshall Islands  Immigrants  Foreigners   909  Oceania   954
# 193    Western Sahara  Immigrants  Foreigners   903   Africa   912
# 194             Palau  Immigrants  Foreigners   909  Oceania   954
#
#                 RegName  DEV             DevName   1980  ...   2005   2006  \
# 0         Southern Asia  902  Developing regions   8880  ...  36210  33848
# ...

# %%
df.rename(columns= {'AreaName':'Continents'}, inplace= True)
df.to_csv('NewCAnada.csv')

# %%
# Indexing the dataset by Counrty
df = dfc.set_index('Country')
df
# Out:
#                         Type    Coverage  AREA Continents   REG  \
# Country
# India             Immigrants  Foreigners   935       Asia  5501
# China             Immigrants  Foreigners   935       Asia   906
# Philippines       Immigrants  Foreigners   935       Asia   920
# UK                Immigrants  Foreigners   908     Europe   924
# Pakistan          Immigrants  Foreigners   935       Asia  5501
# ...                      ...         ...   ...        ...   ...
# American Samoa    Immigrants  Foreigners   909    Oceania   957
# San Marino        Immigrants  Foreigners   908     Europe   925
# Marshall Islands  Immigrants  Foreigners   909    Oceania   954
# Western Sahara    Immigrants  Foreigners   903     Africa   912
# Palau             Immigrants  Foreigners   909    Oceania   954
#
#                              RegName  DEV             DevName   1980   1981  \
# Country
# India                  Southern Asia  902  Developing regions   8880   8670
# ...

# %%
# Grouping the Continents column
df_cont = df.groupby('Continents', axis=0).sum()

# %%
df_cont
# Out:
#                                   AREA     REG    DEV   1980   1981   1982  \
# Continents
# Africa                           48762   49242  48708   3951   4363   3819
# Asia                             45815  109147  44197  31025  34314  30214
# Europe                           39044   39754  38743  39760  44802  42720
# Latin America and the Caribbean  29832   30395  29766  13081  15215  16769
# Northern America                  1810    1810   1802   9378  10030   9074
# Oceania                          12726   13210  12626   1942   1839   1675
#
#                                   1983   1984   1985   1986  ...    2005  \
# Continents                                                   ...
# Africa                            2671   2639   2650   3782  ...   27523
# Asia                             24696  27274  23850  28739  ...  159253
# Europe                           24638  22287  20844  24370  ...   35955
# ...

# %%
# Ploting the Graph
df_cont['Total'].plot(kind='pie')
plt.title('Immigration to Canada by Continent [1980-2013]')
plt.show()
